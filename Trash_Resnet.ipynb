# %%
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import json, io, requests, string
from torch.utils.data.dataset import Dataset
from torchvision import transforms
import pandas as pd
import numpy as np


class CustomDatasetFromImages(Dataset):
    def __init__(self, csv_path):
        """
        Args:
            csv_path (string): path to csv file
            img_path (string): path to the folder where images are
            transform: pytorch transforms for transforms and tensor conversion
        """
        # Transforms
        self.to_tensor = transforms.ToTensor()
        # Read the csv file
        self.data_info = pd.read_csv(csv_path, header=None)
        # First column contains the image paths
        self.image_arr = np.asarray(self.data_info.iloc[:, 0])
        # Second column is the labels
        self.label_arr = np.asarray(self.data_info.iloc[:, 1])
        # Third column is for an operation indicator
        self.operation_arr = np.asarray(self.data_info.iloc[:, 2])
        # Calculate len
        self.data_len = len(self.data_info.index)

    def __getitem__(self, index):
        # Get image name from the pandas df
        single_image_name = self.image_arr[index]
        # Open image
        img_as_img = Image.open(single_image_name)

        # Check if there is an operation
        some_operation = self.operation_arr[index]
        # If there is an operation
        if some_operation:
            # Do some operation on image
            # ...
            # ...
            pass
        # Transform image to tensor
        img_as_tensor = self.to_tensor(img_as_img)

        # Get label(class) of the image based on the cropped pandas column
        single_image_label = self.label_arr[index]

        return (img_as_tensor, single_image_label)

    def __len__(self):
        return self.data_len
if __name__ == "__main__":
    # Define transforms
    
    # Define custom dataset
    train_data = CustomDatasetFromImages("Train0.csv")
    validation_data = CustomDatasetFromImages("Val0.csv")
    
    # Define data loader
#     trainset = torch.utils.data.DataLoader(dataset=train_data,
#                                                     batch_size=100,
#                                                     shuffle=True)
    
#     valset = torch.utils.data.DataLoader(dataset=validation_data,
#                                                     batch_size=100,
#                                                     shuffle=False)
    
    #for images, labels in trainset:
        # Feed the data to the model

# %%
resnet152 = models.resnet18(pretrained=True)
resnet152.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import FashionMNIST
import torch.optim as optim

preprocessFn = transforms.Compose(
    [transforms.Resize(256),  # 1. Resize smallest side to 256.
     transforms.CenterCrop(224), # 2. Crop the center 224x224 pixels.
     transforms.ToTensor(),
     transforms.Normalize(mean = [0.485, 0.456, 0.406],  # normalize.
                          std = [0.229, 0.224, 0.225])])
print(type(train_data))
# img = []
# labellist = []
imgtensor = torch.zeros(1768,3,224,224)
labeltensor = torch.LongTensor(1768,1).zero_()
counter = 0
for (i, (inputs, labels)) in enumerate(train_data):
    counter += 1
    art= transforms.ToPILImage()(inputs)
    imgtensor[i,:,:,:] = preprocessFn(art).unsqueeze(0)
#     print(labels)
    labeltensor[i,:] = torch.tensor(labels)

imgtensorVal = torch.zeros(328,3,224,224)
labeltensorVal = torch.LongTensor(328,1).zero_()
counter = 0
for (i, (inputs, labels)) in enumerate(validation_data):
    counter += 1
    art= transforms.ToPILImage()(inputs)
    imgtensorVal[i,:,:,:] = preprocessFn(art).unsqueeze(0)
#     print(labels)
    labeltensorVal[i,:] = torch.tensor(labels)
    
print(counter)
# Load the training, and validation datasets.
# Out:
# <class '__main__.CustomDatasetFromImages'>
# 326

# %%
from random import shuffle
# randomizer = [i for i in range(2390)]
# shuffle(randomizer)
# print(randomizer)

train_accuracies = []; val_accuracies = []
train_losses = []; val_losses = []

trainset = torch.utils.data.TensorDataset(imgtensor, labeltensor)
valset = torch.utils.data.TensorDataset(imgtensorVal, labeltensorVal)

print(type(imgtensor))
print(imgtensor[0].shape)

def train_model(model, loss_fn, batchSize, trainset, valset, optimizer):
  
  # Shuffling is needed in case dataset is not shuffled by default.
  train_loader = torch.utils.data.DataLoader(dataset = trainset,
                                              batch_size = batchSize,
                                              shuffle = True)
#   # We don't need to bach the validation set but let's do it anyway.
  val_loader = torch.utils.data.DataLoader(dataset = valset,
                                             batch_size = batchSize,
                                             shuffle = False) # No need.
  
  # Define number of epochs.
  N = 5

  # log accuracies and losses.
  train_accuracies = []; val_accuracies = []
  train_losses = []; val_losses = []

  # GPU enabling.
  model = model.cuda()
  loss_fn = loss_fn.cuda()


  # Training loop. Please make sure you understand every single line of code below.
  # Go back to some of the previous steps in this lab if necessary.
  for epoch in range(0, N):
      correct = 0.0
      cum_loss = 0.0

      # Make a pass over the training data.
      #model.train()
      for (i, (inputs, labels)) in enumerate(train_loader):
          #print(type(inputs))
          inputs = inputs.cuda()
          labels = labels.cuda()
          #print(inputs.shape)
          #trans = transforms.ToPILImage()
          #img = transforms.ToPILImage()(inputs)
          #pil_img = trans(inputs)
          #input_img =  preprocessFn(pil_img).unsqueeze(0)
          # Forward pass. (Prediction stage)
          scores = model(inputs)
#           print(labels)
          loss = loss_fn(scores, labels.view(-1))
#           print(labels.view(-1))
#           print(scores.shape)
          # Count how many correct in this batch.
          max_scores, max_labels = scores.max(1)
#           print(max_labels)
#           print(labels.view(-1))
          correct += (max_labels == labels.view(-1)).sum().item()
          cum_loss += loss.item()

          # Zero the gradients in the network.
          optimizer.zero_grad()

          #Backward pass. (Gradient computation stage)
          loss.backward()

          # Parameter updates (SGD step) -- if done with torch.optim!
          optimizer.step()
          # Parameter updates (SGD step) -- if done manually!
          # for param in model.parameters():
          #   param.data.add_(-learningRate, param.grad)

          # Logging the current results on training.
          if (i + 1) % 10 == 0:
              print('Train-epoch %d. Iteration %05d, Avg-Loss: %.4f, Accuracy: %.4f' % 
                    (epoch, i + 1, cum_loss / (i + 1), correct / ((i + 1) * batchSize)))


      train_accuracies.append(correct / len(trainset))
      train_losses.append(cum_loss / (i + 1))   

      # Make a pass over the validation data.
      correct = 0.0
      cum_loss = 0.0
      model.eval()
      for (i, (inputs, labels)) in enumerate(val_loader):
           inputs = inputs.cuda()
           labels = labels.cuda()


#           # Forward pass. (Prediction stage)
           scores = model(inputs)
           cum_loss += loss_fn(scores, labels.view(-1)).item()

#            # Count how many correct in this batch.
           max_scores, max_labels = scores.max(1)
           correct += (max_labels == labels.view(-1)).sum().item()

      val_accuracies.append(correct / len(valset))
      val_losses.append(cum_loss / (i + 1))
      
      # Logging the current results on validation.
      print('Validation-epoch %d. Avg-Loss: %.4f, Accuracy: %.4f' % 
            (epoch, cum_loss / (i + 1), correct / len(valset)))
    
  fig = plt.figure(figsize = (10, 4))
  fig.suptitle('Resnet152 Results', fontsize=14, fontweight='bold')
  plt.subplot(1, 2, 1)
  plt.plot(val_losses, 'bo-', label = 'val-loss')
  plt.plot(train_losses, 'ro-', label = 'train-loss') 
  plt.ylabel('loss')
  plt.xlabel('epoch') 
  plt.legend(['validation', 'training'], loc='upper right')

  plt.subplot(1, 2, 2)
  plt.plot(val_accuracies, 'bo-', label = 'val-acc')
  plt.plot(train_accuracies, 'ro-', label = 'train-acc')
  plt.ylabel('accuracy')
  plt.xlabel('epoch') 
  plt.legend(['validation', 'training'], loc='lower right')
  plt.show()      


      
model = resnet152
loss_fn = nn.CrossEntropyLoss()
    
# Create the model.
# Optimizer.
learningRate = 1e-4
optimizer = optim.Adam(model.parameters(), lr = learningRate)
batchSize = 5

train_model(model, loss_fn, batchSize, trainset, valset, optimizer)
# Out:
# <class 'torch.Tensor'>
# torch.Size([3, 224, 224])
# Train-epoch 0. Iteration 00010, Avg-Loss: 4.2258, Accuracy: 0.1200
# Train-epoch 0. Iteration 00020, Avg-Loss: 3.2131, Accuracy: 0.2500
# Train-epoch 0. Iteration 00030, Avg-Loss: 2.7514, Accuracy: 0.2533
# Train-epoch 0. Iteration 00040, Avg-Loss: 2.6517, Accuracy: 0.2500
# Train-epoch 0. Iteration 00050, Avg-Loss: 2.5007, Accuracy: 0.2720
# Train-epoch 0. Iteration 00060, Avg-Loss: 2.3416, Accuracy: 0.2867
# Train-epoch 0. Iteration 00070, Avg-Loss: 2.2030, Accuracy: 0.3200
# Train-epoch 0. Iteration 00080, Avg-Loss: 2.1183, Accuracy: 0.3375
# Train-epoch 0. Iteration 00090, Avg-Loss: 2.0173, Accuracy: 0.3644
# Train-epoch 0. Iteration 00100, Avg-Loss: 1.9219, Accuracy: 0.3860
# Train-epoch 0. Iteration 00110, Avg-Loss: 1.8874, Accuracy: 0.3964
# Train-epoch 0. Iteration 00120, Avg-Loss: 1.8328, Accuracy: 0.4017
# Train-epoch 0. Iteration 00130, Avg-Loss: 1.7697, Accuracy: 0.4138
# Train-epoch 0. Iteration 00140, Avg-Loss: 1.7297, Accuracy: 0.4271
# Train-epoch 0. Iteration 00150, Avg-Loss: 1.6846, Accuracy: 0.4373
# Train-epoch 0. Iteration 00160, Avg-Loss: 1.6479, Accuracy: 0.4475
# Train-epoch 0. Iteration 00170, Avg-Loss: 1.6160, Accuracy: 0.4553
# Train-epoch 0. Iteration 00180, Avg-Loss: 1.5769, Accuracy: 0.4678
# Train-epoch 0. Iteration 00190, Avg-Loss: 1.5414, Accuracy: 0.4758
# Train-epoch 0. Iteration 00200, Avg-Loss: 1.5192, Accuracy: 0.4800
# Train-epoch 0. Iteration 00210, Avg-Loss: 1.5054, Accuracy: 0.4867
# Train-epoch 0. Iteration 00220, Avg-Loss: 1.4905, Accuracy: 0.4936
# Train-epoch 0. Iteration 00230, Avg-Loss: 1.4711, Accuracy: 0.4948
# Train-epoch 0. Iteration 00240, Avg-Loss: 1.4430, Accuracy: 0.5042
# Train-epoch 0. Iteration 00250, Avg-Loss: 1.4278, Accuracy: 0.5088
# Train-epoch 0. Iteration 00260, Avg-Loss: 1.4043, Accuracy: 0.5169
# Train-epoch 0. Iteration 00270, Avg-Loss: 1.3904, Accuracy: 0.5230
# Train-epoch 0. Iteration 00280, Avg-Loss: 1.3750, Accuracy: 0.5300
# Train-epoch 0. Iteration 00290, Avg-Loss: 1.3665, Accuracy: 0.5324
# Train-epoch 0. Iteration 00300, Avg-Loss: 1.3529, Accuracy: 0.5353
# Train-epoch 0. Iteration 00310, Avg-Loss: 1.3353, Accuracy: 0.5419
# Train-epoch 0. Iteration 00320, Avg-Loss: 1.3276, Accuracy: 0.5419
# Train-epoch 0. Iteration 00330, Avg-Loss: 1.3133, Accuracy: 0.5473
# Train-epoch 0. Iteration 00340, Avg-Loss: 1.2999, Accuracy: 0.5524
# Train-epoch 0. Iteration 00350, Avg-Loss: 1.2835, Accuracy: 0.5560
# Validation-epoch 0. Avg-Loss: 0.9259, Accuracy: 0.6951
# Train-epoch 1. Iteration 00010, Avg-Loss: 0.9693, Accuracy: 0.6600
# Train-epoch 1. Iteration 00020, Avg-Loss: 0.8856, Accuracy: 0.7100
# Train-epoch 1. Iteration 00030, Avg-Loss: 0.8024, Accuracy: 0.7000
# Train-epoch 1. Iteration 00040, Avg-Loss: 0.7405, Accuracy: 0.7250
# Train-epoch 1. Iteration 00050, Avg-Loss: 0.6861, Accuracy: 0.7480
# Train-epoch 1. Iteration 00060, Avg-Loss: 0.6627, Accuracy: 0.7633
# Train-epoch 1. Iteration 00070, Avg-Loss: 0.7133, Accuracy: 0.7486
# Train-epoch 1. Iteration 00080, Avg-Loss: 0.7057, Accuracy: 0.7475
# Train-epoch 1. Iteration 00090, Avg-Loss: 0.7103, Accuracy: 0.7511
# Train-epoch 1. Iteration 00100, Avg-Loss: 0.7337, Accuracy: 0.7380
# Train-epoch 1. Iteration 00110, Avg-Loss: 0.7435, Accuracy: 0.7364
# Train-epoch 1. Iteration 00120, Avg-Loss: 0.7861, Accuracy: 0.7233
# Train-epoch 1. Iteration 00130, Avg-Loss: 0.7804, Accuracy: 0.7215
# Train-epoch 1. Iteration 00140, Avg-Loss: 0.7635, Accuracy: 0.7271
# Train-epoch 1. Iteration 00150, Avg-Loss: 0.7652, Accuracy: 0.7307
# Train-epoch 1. Iteration 00160, Avg-Loss: 0.7686, Accuracy: 0.7262
# Train-epoch 1. Iteration 00170, Avg-Loss: 0.7803, Accuracy: 0.7224
# Train-epoch 1. Iteration 00180, Avg-Loss: 0.7819, Accuracy: 0.7233
# Train-epoch 1. Iteration 00190, Avg-Loss: 0.7869, Accuracy: 0.7179
# Train-epoch 1. Iteration 00200, Avg-Loss: 0.7832, Accuracy: 0.7190
# Train-epoch 1. Iteration 00210, Avg-Loss: 0.7760, Accuracy: 0.7210
# Train-epoch 1. Iteration 00220, Avg-Loss: 0.7872, Accuracy: 0.7182
# Train-epoch 1. Iteration 00230, Avg-Loss: 0.7958, Accuracy: 0.7148
# Train-epoch 1. Iteration 00240, Avg-Loss: 0.7923, Accuracy: 0.7158
# Train-epoch 1. Iteration 00250, Avg-Loss: 0.7891, Accuracy: 0.7144
# Train-epoch 1. Iteration 00260, Avg-Loss: 0.7909, Accuracy: 0.7131
# Train-epoch 1. Iteration 00270, Avg-Loss: 0.7845, Accuracy: 0.7156
# Train-epoch 1. Iteration 00280, Avg-Loss: 0.7740, Accuracy: 0.7186
# Train-epoch 1. Iteration 00290, Avg-Loss: 0.7622, Accuracy: 0.7234
# Train-epoch 1. Iteration 00300, Avg-Loss: 0.7685, Accuracy: 0.7233
# Train-epoch 1. Iteration 00310, Avg-Loss: 0.7648, Accuracy: 0.7226
# Train-epoch 1. Iteration 00320, Avg-Loss: 0.7612, Accuracy: 0.7250
# Train-epoch 1. Iteration 00330, Avg-Loss: 0.7597, Accuracy: 0.7267
# Train-epoch 1. Iteration 00340, Avg-Loss: 0.7510, Accuracy: 0.7300
# Train-epoch 1. Iteration 00350, Avg-Loss: 0.7540, Accuracy: 0.7320
# Validation-epoch 1. Avg-Loss: 0.8036, Accuracy: 0.7073
# Train-epoch 2. Iteration 00010, Avg-Loss: 0.5587, Accuracy: 0.8400
# Train-epoch 2. Iteration 00020, Avg-Loss: 0.6318, Accuracy: 0.7500
# Train-epoch 2. Iteration 00030, Avg-Loss: 0.5858, Accuracy: 0.7867
# Train-epoch 2. Iteration 00040, Avg-Loss: 0.4841, Accuracy: 0.8350
# Train-epoch 2. Iteration 00050, Avg-Loss: 0.4626, Accuracy: 0.8440
# Train-epoch 2. Iteration 00060, Avg-Loss: 0.4476, Accuracy: 0.8467
# Train-epoch 2. Iteration 00070, Avg-Loss: 0.4604, Accuracy: 0.8286
# Train-epoch 2. Iteration 00080, Avg-Loss: 0.4574, Accuracy: 0.8325
# Train-epoch 2. Iteration 00090, Avg-Loss: 0.4390, Accuracy: 0.8378
# Train-epoch 2. Iteration 00100, Avg-Loss: 0.4152, Accuracy: 0.8500
# Train-epoch 2. Iteration 00110, Avg-Loss: 0.4109, Accuracy: 0.8527
# Train-epoch 2. Iteration 00120, Avg-Loss: 0.4024, Accuracy: 0.8567
# Train-epoch 2. Iteration 00130, Avg-Loss: 0.4019, Accuracy: 0.8585
# Train-epoch 2. Iteration 00140, Avg-Loss: 0.4201, Accuracy: 0.8543
# Train-epoch 2. Iteration 00150, Avg-Loss: 0.4110, Accuracy: 0.8573
# Train-epoch 2. Iteration 00160, Avg-Loss: 0.4115, Accuracy: 0.8562
# Train-epoch 2. Iteration 00170, Avg-Loss: 0.4158, Accuracy: 0.8518
# Train-epoch 2. Iteration 00180, Avg-Loss: 0.4198, Accuracy: 0.8489
# Train-epoch 2. Iteration 00190, Avg-Loss: 0.4230, Accuracy: 0.8505
# Train-epoch 2. Iteration 00200, Avg-Loss: 0.4222, Accuracy: 0.8510
# Train-epoch 2. Iteration 00210, Avg-Loss: 0.4351, Accuracy: 0.8495
# Train-epoch 2. Iteration 00220, Avg-Loss: 0.4332, Accuracy: 0.8500
# Train-epoch 2. Iteration 00230, Avg-Loss: 0.4362, Accuracy: 0.8496
# Train-epoch 2. Iteration 00240, Avg-Loss: 0.4290, Accuracy: 0.8533
# Train-epoch 2. Iteration 00250, Avg-Loss: 0.4254, Accuracy: 0.8544
# Train-epoch 2. Iteration 00260, Avg-Loss: 0.4355, Accuracy: 0.8500
# Train-epoch 2. Iteration 00270, Avg-Loss: 0.4289, Accuracy: 0.8526
# Train-epoch 2. Iteration 00280, Avg-Loss: 0.4252, Accuracy: 0.8536
# Train-epoch 2. Iteration 00290, Avg-Loss: 0.4187, Accuracy: 0.8552
# Train-epoch 2. Iteration 00300, Avg-Loss: 0.4255, Accuracy: 0.8533
# Train-epoch 2. Iteration 00310, Avg-Loss: 0.4327, Accuracy: 0.8490
# Train-epoch 2. Iteration 00320, Avg-Loss: 0.4305, Accuracy: 0.8506
# Train-epoch 2. Iteration 00330, Avg-Loss: 0.4260, Accuracy: 0.8527
# Train-epoch 2. Iteration 00340, Avg-Loss: 0.4242, Accuracy: 0.8541
# Train-epoch 2. Iteration 00350, Avg-Loss: 0.4339, Accuracy: 0.8503
# Validation-epoch 2. Avg-Loss: 0.6795, Accuracy: 0.7561
# Train-epoch 3. Iteration 00010, Avg-Loss: 0.2478, Accuracy: 0.9200
# Train-epoch 3. Iteration 00020, Avg-Loss: 0.2395, Accuracy: 0.9100
# Train-epoch 3. Iteration 00030, Avg-Loss: 0.2288, Accuracy: 0.9067
# Train-epoch 3. Iteration 00040, Avg-Loss: 0.3471, Accuracy: 0.8700
# Train-epoch 3. Iteration 00050, Avg-Loss: 0.3207, Accuracy: 0.8840
# Train-epoch 3. Iteration 00060, Avg-Loss: 0.3164, Accuracy: 0.8800
# Train-epoch 3. Iteration 00070, Avg-Loss: 0.3165, Accuracy: 0.8886
# Train-epoch 3. Iteration 00080, Avg-Loss: 0.3087, Accuracy: 0.8925
# Train-epoch 3. Iteration 00090, Avg-Loss: 0.3103, Accuracy: 0.8911
# Train-epoch 3. Iteration 00100, Avg-Loss: 0.3306, Accuracy: 0.8840
# Train-epoch 3. Iteration 00110, Avg-Loss: 0.3262, Accuracy: 0.8873
# Train-epoch 3. Iteration 00120, Avg-Loss: 0.3439, Accuracy: 0.8800
# Train-epoch 3. Iteration 00130, Avg-Loss: 0.3566, Accuracy: 0.8754
# Train-epoch 3. Iteration 00140, Avg-Loss: 0.3655, Accuracy: 0.8757
# Train-epoch 3. Iteration 00150, Avg-Loss: 0.3621, Accuracy: 0.8787
# Train-epoch 3. Iteration 00160, Avg-Loss: 0.3519, Accuracy: 0.8788
# Train-epoch 3. Iteration 00170, Avg-Loss: 0.3375, Accuracy: 0.8835
# Train-epoch 3. Iteration 00180, Avg-Loss: 0.3379, Accuracy: 0.8844
# Train-epoch 3. Iteration 00190, Avg-Loss: 0.3311, Accuracy: 0.8863
# Train-epoch 3. Iteration 00200, Avg-Loss: 0.3224, Accuracy: 0.8890
# Train-epoch 3. Iteration 00210, Avg-Loss: 0.3292, Accuracy: 0.8848
# Train-epoch 3. Iteration 00220, Avg-Loss: 0.3392, Accuracy: 0.8827
# Train-epoch 3. Iteration 00230, Avg-Loss: 0.3543, Accuracy: 0.8765
# Train-epoch 3. Iteration 00240, Avg-Loss: 0.3572, Accuracy: 0.8758
# Train-epoch 3. Iteration 00250, Avg-Loss: 0.3523, Accuracy: 0.8784
# Train-epoch 3. Iteration 00260, Avg-Loss: 0.3558, Accuracy: 0.8777
# Train-epoch 3. Iteration 00270, Avg-Loss: 0.3530, Accuracy: 0.8778
# Train-epoch 3. Iteration 00280, Avg-Loss: 0.3576, Accuracy: 0.8779
# Train-epoch 3. Iteration 00290, Avg-Loss: 0.3625, Accuracy: 0.8752
# Train-epoch 3. Iteration 00300, Avg-Loss: 0.3733, Accuracy: 0.8733
# Train-epoch 3. Iteration 00310, Avg-Loss: 0.3811, Accuracy: 0.8703
# Train-epoch 3. Iteration 00320, Avg-Loss: 0.3864, Accuracy: 0.8688
# Train-epoch 3. Iteration 00330, Avg-Loss: 0.3880, Accuracy: 0.8691
# Train-epoch 3. Iteration 00340, Avg-Loss: 0.3879, Accuracy: 0.8706
# Train-epoch 3. Iteration 00350, Avg-Loss: 0.3919, Accuracy: 0.8697
# Validation-epoch 3. Avg-Loss: 0.4735, Accuracy: 0.8354
# Train-epoch 4. Iteration 00010, Avg-Loss: 0.1247, Accuracy: 0.9600
# Train-epoch 4. Iteration 00020, Avg-Loss: 0.1742, Accuracy: 0.9400
# Train-epoch 4. Iteration 00030, Avg-Loss: 0.2103, Accuracy: 0.9200
# Train-epoch 4. Iteration 00040, Avg-Loss: 0.2012, Accuracy: 0.9250
# Train-epoch 4. Iteration 00050, Avg-Loss: 0.2047, Accuracy: 0.9280
# Train-epoch 4. Iteration 00060, Avg-Loss: 0.1870, Accuracy: 0.9367
# Train-epoch 4. Iteration 00070, Avg-Loss: 0.1890, Accuracy: 0.9429
# Train-epoch 4. Iteration 00080, Avg-Loss: 0.1875, Accuracy: 0.9375
# Train-epoch 4. Iteration 00090, Avg-Loss: 0.1859, Accuracy: 0.9378
# Train-epoch 4. Iteration 00100, Avg-Loss: 0.1968, Accuracy: 0.9340
# Train-epoch 4. Iteration 00110, Avg-Loss: 0.2226, Accuracy: 0.9291
# Train-epoch 4. Iteration 00120, Avg-Loss: 0.2216, Accuracy: 0.9300
# Train-epoch 4. Iteration 00130, Avg-Loss: 0.2219, Accuracy: 0.9308
# Train-epoch 4. Iteration 00140, Avg-Loss: 0.2488, Accuracy: 0.9229
# Train-epoch 4. Iteration 00150, Avg-Loss: 0.2486, Accuracy: 0.9240
# Train-epoch 4. Iteration 00160, Avg-Loss: 0.2547, Accuracy: 0.9213
# Train-epoch 4. Iteration 00170, Avg-Loss: 0.2547, Accuracy: 0.9212
# Train-epoch 4. Iteration 00180, Avg-Loss: 0.2499, Accuracy: 0.9233
# Train-epoch 4. Iteration 00190, Avg-Loss: 0.2460, Accuracy: 0.9253
# Train-epoch 4. Iteration 00200, Avg-Loss: 0.2410, Accuracy: 0.9270
# Train-epoch 4. Iteration 00210, Avg-Loss: 0.2334, Accuracy: 0.9295
# Train-epoch 4. Iteration 00220, Avg-Loss: 0.2278, Accuracy: 0.9318
# Train-epoch 4. Iteration 00230, Avg-Loss: 0.2351, Accuracy: 0.9278
# Train-epoch 4. Iteration 00240, Avg-Loss: 0.2353, Accuracy: 0.9258
# Train-epoch 4. Iteration 00250, Avg-Loss: 0.2356, Accuracy: 0.9248
# Train-epoch 4. Iteration 00260, Avg-Loss: 0.2369, Accuracy: 0.9246
# Train-epoch 4. Iteration 00270, Avg-Loss: 0.2447, Accuracy: 0.9207
# Train-epoch 4. Iteration 00280, Avg-Loss: 0.2418, Accuracy: 0.9207
# Train-epoch 4. Iteration 00290, Avg-Loss: 0.2390, Accuracy: 0.9207
# Train-epoch 4. Iteration 00300, Avg-Loss: 0.2419, Accuracy: 0.9180
# Train-epoch 4. Iteration 00310, Avg-Loss: 0.2413, Accuracy: 0.9168
# Train-epoch 4. Iteration 00320, Avg-Loss: 0.2395, Accuracy: 0.9175
# Train-epoch 4. Iteration 00330, Avg-Loss: 0.2402, Accuracy: 0.9182
# Train-epoch 4. Iteration 00340, Avg-Loss: 0.2398, Accuracy: 0.9176
# Train-epoch 4. Iteration 00350, Avg-Loss: 0.2415, Accuracy: 0.9166
# Validation-epoch 4. Avg-Loss: 0.5744, Accuracy: 0.8140

# %%
#Confusion Matrix Part
import numpy as np
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import confusion_matrix

from sklearn.metrics import recall_score
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import label_binarize
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import confusion_matrix
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.utils.multiclass import unique_labels

import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import json, io, requests, string
from torch.utils.data.dataset import Dataset
from torchvision import transforms
import pandas as pd
import numpy as np

class_names = ['Glass', 'Paper', 'Cardboard', 'Plastic', 'Metal', 'Trash' ]

score_list = []
label_list = []
ypred_list = []
y_pred = []
ytrue_list = []

def precisionrecall():
    batchSize = 5
#     model_load = torch.load("D:/trainedmodel_inceptionV3.pth")
    val_loader = torch.utils.data.DataLoader(dataset = valset,
                                             batch_size = batchSize,
                                             shuffle = False) # No need.
    model_load = model

    model_load.eval()



    
    
    for (i, (inputs, labels)) in enumerate(val_loader):
        
        inputs = inputs.cuda()
        labels = labels.cuda()

        #           # Forward pass. (Prediction stage)
        scores = model_load(inputs)
        
        #            # Count how many correct in this batch.
        max_scores, max_labels = scores.max(1)
        y_pred.append(max_labels.cpu().tolist())

#         stores the scores and labels for computation of the precision recall curve
        score_list.append(scores.cpu().tolist())
        label_list.append(labels.view(-1).cpu().tolist())
        
    scoreholder = [[] for i in range(0,6)]

    class_counter = 0
    
    for class_counter in range(0,6):
        for i in score_list:
            for counter in  range(0,len(i)):
                try:
                    scoreholder[class_counter].append(i[counter][class_counter])
                except IndexError:
                    print(i)
                    break
                    
    for i in y_pred:
        for counter in  i:
            ypred_list.append(counter)
               


    precision = []

    ## Here we merge the datas of each epoch in tensor form (concantation)

    print(len(label_list))
    print(len(label_list[0]))
    
    print(len(score_list))
    print(len(score_list[0]))
    print(len(score_list[0][0]))
    
    for element in label_list:
        for subelement in element:

            ytrue_list.append(subelement)

    x = label_binarize(ytrue_list, classes=[0, 1, 2, 3, 4, 5])
    
    print(len(scoreholder[0]))
    print(len(x))
    
    
    precision= [0]*6
    recall = [0]*6
    average_precision = [0] * 6
    for i in range(0,6):
        precision[i], recall[i], _ = precision_recall_curve(x[:, i], np.asarray(scoreholder[i]))

        average_precision[i] = average_precision_score(x[:, i], np.asarray(scoreholder[i]))


    for i in range(0,6):
        plt.step(recall[i], precision[i], label= class_names[i], linewidth = 0.5)
    plt.legend()

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
#     plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
#               average_precision[1]))
    plt.savefig('precision-recall-resnet.png', dpi = 720)

    


                          
precisionrecall()
# Out:
# 66
# 5
# 66
# 5
# 1000
# 328
# 328

# %%
#Confusion Matrix Part
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.utils.multiclass import unique_labels
import numpy as np
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import confusion_matrix


normalize = True
tensorino = torch.tensor([1])
ytrue_list = []

for element in label_list:
        for subelement in element:

            ytrue_list.append(subelement)

    
# print(tensorino)

print(np.asarray(ytrue_list))
class_names = ['Glass', 'Paper', 'Cardboard', 'Plastic', 'Metal', 'Trash' ]
print(confusion_matrix(ytrue_list, ypred_list))

# plot_confusion_matrix(np.asarray(ytrue_list[-1].tolist()), np.asarray(ypred_list[-1].tolist()), classes=class_names,
#                       normalize=False)
cm = confusion_matrix(ytrue_list,ypred_list)
piun = [0]*6
for i in range(0, cm.shape[1]):
    piun[i] =  np.ndarray.tolist(np.divide(cm[i],np.sum(cm[i])))

cm = np.asarray(piun)
fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap = plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
ax.set(xticks=np.arange(cm.shape[1]),
        yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
        xticklabels=class_names, yticklabels=class_names,
        title="Confusion Matrix",
        ylabel='True label',
        xlabel='Predicted label')
thresh = cm.max() / 1.5 if normalize else cm.max() / 2
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    if normalize:
            plt.text(j, i, "{:0.2f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    else:
        plt.text(j, i, "{:,}".format(cm[i, j]),
                    horizontalalignment="center",
                    color="white" if cm[i, j] > thresh else "black")
plt.xticks( rotation=30)
print(cm)
plt.imshow(cm, cmap = plt.cm.Blues)
# Out:
# [2 3 0 0 0 2 4 5 0 1 2 4 1 0 0 0 1 5 3 2 3 1 0 3 0 3 3 4 1 1 0 1 2 1 0 3 3
#  4 4 4 3 1 2 0 4 4 2 0 5 1 1 1 2 2 3 0 3 2 4 4 0 4 0 5 0 2 0 2 1 3 2 5 4 1
#  1 1 1 0 1 4 0 2 3 4 2 0 3 1 0 1 0 1 3 2 4 1 0 3 1 1 2 0 2 3 3 0 4 3 2 3 1
#  0 3 2 3 3 2 2 4 4 0 2 2 2 1 4 0 1 3 0 4 3 0 1 1 3 5 3 3 1 0 3 1 3 3 0 4 0
#  1 0 0 1 4 3 4 3 0 1 0 0 3 2 0 3 3 4 2 3 5 0 1 0 3 0 1 3 3 1 0 5 2 1 1 2 0
#  1 5 1 4 2 1 1 2 4 1 4 3 1 4 1 3 1 4 2 1 0 1 4 1 4 2 2 1 2 3 4 5 1 1 3 2 0
#  5 0 1 1 2 1 1 1 3 0 3 0 5 1 1 3 2 0 0 0 1 0 0 0 2 1 4 4 1 0 0 5 1 5 1 1 5
#  4 2 1 1 4 1 2 3 0 4 1 4 3 3 4 5 2 4 3 5 1 1 1 4 3 4 4 1 2 4 2 0 3 3 4 3 1
#  4 1 1 4 4 0 4 3 4 3 4 4 4 4 1 1 3 1 0 1 3 0 4 2 0 4 2 3 0 1 0 0]
# [[51  0  0  9  7  0]
#  [ 0 66  2  7  7  0]
#  [ 0  1 43  2  0  0]
#  [ 2  1  1 55  1  0]
#  [ 3  0  0  8 45  0]
#  [ 1  0  1  6  2  7]]
# [[0.76119403 0.         0.         0.13432836 0.10447761 0.        ]
#  [0.         0.80487805 0.02439024 0.08536585 0.08536585 0.        ]
#  [0.         0.02173913 0.93478261 0.04347826 0.         0.        ]
#  [0.03333333 0.01666667 0.01666667 0.91666667 0.01666667 0.        ]
#  [0.05357143 0.         0.         0.14285714 0.80357143 0.        ]
#  [0.05882353 0.         0.05882353 0.35294118 0.11764706 0.41176471]]
