# %%
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import json, io, requests, string
from torch.utils.data.dataset import Dataset
from torchvision import transforms
import pandas as pd
import numpy as np


class CustomDatasetFromImages(Dataset):
    def __init__(self, csv_path):
        """
        Args:
            csv_path (string): path to csv file
            img_path (string): path to the folder where images are
            transform: pytorch transforms for transforms and tensor conversion
        """
        # Transforms
        self.to_tensor = transforms.ToTensor()
        # Read the csv file
        self.data_info = pd.read_csv(csv_path, header=None)
        # First column contains the image paths
        self.image_arr = np.asarray(self.data_info.iloc[:, 0])
        # Second column is the labels
        self.label_arr = np.asarray(self.data_info.iloc[:, 1])
        # Third column is for an operation indicator
        self.operation_arr = np.asarray(self.data_info.iloc[:, 2])
        # Calculate len
        self.data_len = len(self.data_info.index)

    def __getitem__(self, index):
        # Get image name from the pandas df
        single_image_name = self.image_arr[index]
        # Open image
        img_as_img = Image.open(single_image_name)

        # Check if there is an operation
        some_operation = self.operation_arr[index]
        # If there is an operation
        if some_operation:
            # Do some operation on image
            # ...
            # ...
            pass
        # Transform image to tensor
        img_as_tensor = self.to_tensor(img_as_img)

        # Get label(class) of the image based on the cropped pandas column
        single_image_label = self.label_arr[index]

        return (img_as_tensor, single_image_label)

    def __len__(self):
        return self.data_len
if __name__ == "__main__":
    # Define transforms
    
    # Define custom dataset
    train_data = CustomDatasetFromImages("Train0.csv")
    validation_data = CustomDatasetFromImages("Val0.csv")
    
    # Define data loader
#     trainset = torch.utils.data.DataLoader(dataset=train_data,
#                                                     batch_size=100,
#                                                     shuffle=True)
    
#     valset = torch.utils.data.DataLoader(dataset=validation_data,
#                                                     batch_size=100,
#                                                     shuffle=False)
    
    #for images, labels in trainset:
        # Feed the data to the model

# %%
resnet152 = models.resnet152(pretrained=True)
resnet152.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import FashionMNIST
import torch.optim as optim

preprocessFn = transforms.Compose(
    [transforms.Resize(256),  # 1. Resize smallest side to 256.
     transforms.CenterCrop(224), # 2. Crop the center 224x224 pixels.
     transforms.ToTensor(),
     transforms.Normalize(mean = [0.485, 0.456, 0.406],  # normalize.
                          std = [0.229, 0.224, 0.225])])
print(type(train_data))
# img = []
# labellist = []
imgtensor = torch.zeros(1768,3,224,224)
labeltensor = torch.LongTensor(1768,1).zero_()
counter = 0
for (i, (inputs, labels)) in enumerate(train_data):
    counter += 1
    art= transforms.ToPILImage()(inputs)
    imgtensor[i,:,:,:] = preprocessFn(art).unsqueeze(0)
#     print(labels)
    labeltensor[i,:] = torch.tensor(labels)

imgtensorVal = torch.zeros(328,3,224,224)
labeltensorVal = torch.LongTensor(328,1).zero_()
counter = 0
for (i, (inputs, labels)) in enumerate(validation_data):
    counter += 1
    art= transforms.ToPILImage()(inputs)
    imgtensorVal[i,:,:,:] = preprocessFn(art).unsqueeze(0)
#     print(labels)
    labeltensorVal[i,:] = torch.tensor(labels)
    
print(counter)
# Load the training, and validation datasets.
# Out:
# <class '__main__.CustomDatasetFromImages'>
# 326

# %%
from random import shuffle
# randomizer = [i for i in range(2390)]
# shuffle(randomizer)
# print(randomizer)

train_accuracies = []; val_accuracies = []
train_losses = []; val_losses = []

trainset = torch.utils.data.TensorDataset(imgtensor, labeltensor)
valset = torch.utils.data.TensorDataset(imgtensorVal, labeltensorVal)

print(type(imgtensor))
print(imgtensor[0].shape)

def train_model(model, loss_fn, batchSize, trainset, valset, optimizer):
  
  # Shuffling is needed in case dataset is not shuffled by default.
  train_loader = torch.utils.data.DataLoader(dataset = trainset,
                                              batch_size = batchSize,
                                              shuffle = True)
#   # We don't need to bach the validation set but let's do it anyway.
  val_loader = torch.utils.data.DataLoader(dataset = valset,
                                             batch_size = batchSize,
                                             shuffle = False) # No need.
  
  # Define number of epochs.
  N = 50

  # log accuracies and losses.
  train_accuracies = []; val_accuracies = []
  train_losses = []; val_losses = []

  # GPU enabling.
  model = model.cuda()
  loss_fn = loss_fn.cuda()


  # Training loop. Please make sure you understand every single line of code below.
  # Go back to some of the previous steps in this lab if necessary.
  for epoch in range(0, N):
      correct = 0.0
      cum_loss = 0.0

      # Make a pass over the training data.
      #model.train()
      for (i, (inputs, labels)) in enumerate(train_loader):
          #print(type(inputs))
          inputs = inputs.cuda()
          labels = labels.cuda()
          #print(inputs.shape)
          #trans = transforms.ToPILImage()
          #img = transforms.ToPILImage()(inputs)
          #pil_img = trans(inputs)
          #input_img =  preprocessFn(pil_img).unsqueeze(0)
          # Forward pass. (Prediction stage)
          scores = model(inputs)
#           print(labels)
          loss = loss_fn(scores, labels.view(-1))
#           print(labels.view(-1))
#           print(scores.shape)
          # Count how many correct in this batch.
          max_scores, max_labels = scores.max(1)
#           print(max_labels)
#           print(labels.view(-1))
          correct += (max_labels == labels.view(-1)).sum().item()
          cum_loss += loss.item()

          # Zero the gradients in the network.
          optimizer.zero_grad()

          #Backward pass. (Gradient computation stage)
          loss.backward()

          # Parameter updates (SGD step) -- if done with torch.optim!
          optimizer.step()
          # Parameter updates (SGD step) -- if done manually!
          # for param in model.parameters():
          #   param.data.add_(-learningRate, param.grad)

          # Logging the current results on training.
          if (i + 1) % 10 == 0:
              print('Train-epoch %d. Iteration %05d, Avg-Loss: %.4f, Accuracy: %.4f' % 
                    (epoch, i + 1, cum_loss / (i + 1), correct / ((i + 1) * batchSize)))


      train_accuracies.append(correct / len(trainset))
      train_losses.append(cum_loss / (i + 1))   

      # Make a pass over the validation data.
      correct = 0.0
      cum_loss = 0.0
      model.eval()
      for (i, (inputs, labels)) in enumerate(val_loader):
           inputs = inputs.cuda()
           labels = labels.cuda()


#           # Forward pass. (Prediction stage)
           scores = model(inputs)
           cum_loss += loss_fn(scores, labels.view(-1)).item()

#            # Count how many correct in this batch.
           max_scores, max_labels = scores.max(1)
           correct += (max_labels == labels.view(-1)).sum().item()

      val_accuracies.append(correct / len(valset))
      val_losses.append(cum_loss / (i + 1))
      
      # Logging the current results on validation.
      print('Validation-epoch %d. Avg-Loss: %.4f, Accuracy: %.4f' % 
            (epoch, cum_loss / (i + 1), correct / len(valset)))
    
  fig = plt.figure(figsize = (10, 4))
  fig.suptitle('Resnet152 Results', fontsize=14, fontweight='bold')
  plt.subplot(1, 2, 1)
  plt.plot(val_losses, 'bo-', label = 'val-loss')
  plt.plot(train_losses, 'ro-', label = 'train-loss') 
  plt.ylabel('loss')
  plt.xlabel('epoch') 
  plt.legend(['validation', 'training'], loc='upper right')

  plt.subplot(1, 2, 2)
  plt.plot(val_accuracies, 'bo-', label = 'val-acc')
  plt.plot(train_accuracies, 'ro-', label = 'train-acc')
  plt.ylabel('accuracy')
  plt.xlabel('epoch') 
  plt.legend(['validation', 'training'], loc='lower right')
  plt.show()      



for param in resnet152.parameters():
    param.requires_grad = False
resnet152.fc = nn.Linear(2048, 6)
resnet152.fc.requires_grad = True


model = resnet152

# model = torch.load("D:/Trash_Resnet_Replaced_layer.pth")

loss_fn = nn.CrossEntropyLoss()
    
# Create the model.
# Optimizer.
learningRate = 1e-5
optimizer = optim.Adam(model.parameters(), lr = learningRate)
batchSize = 32

train_model(model, loss_fn, batchSize, trainset, valset, optimizer)
# Out:
# <class 'torch.Tensor'>
# torch.Size([3, 224, 224])
# Train-epoch 0. Iteration 00010, Avg-Loss: 0.4979, Accuracy: 0.8500
# Train-epoch 0. Iteration 00020, Avg-Loss: 0.4730, Accuracy: 0.8734
# Train-epoch 0. Iteration 00030, Avg-Loss: 0.4775, Accuracy: 0.8719
# Train-epoch 0. Iteration 00040, Avg-Loss: 0.4664, Accuracy: 0.8727
# Train-epoch 0. Iteration 00050, Avg-Loss: 0.4742, Accuracy: 0.8644
# Validation-epoch 0. Avg-Loss: 0.4930, Accuracy: 0.8537
# Train-epoch 1. Iteration 00010, Avg-Loss: 0.4927, Accuracy: 0.8250
# Train-epoch 1. Iteration 00020, Avg-Loss: 0.4819, Accuracy: 0.8438
# Train-epoch 1. Iteration 00030, Avg-Loss: 0.4660, Accuracy: 0.8542
# Train-epoch 1. Iteration 00040, Avg-Loss: 0.4571, Accuracy: 0.8609
# Train-epoch 1. Iteration 00050, Avg-Loss: 0.4464, Accuracy: 0.8656
# Validation-epoch 1. Avg-Loss: 0.4810, Accuracy: 0.8567
# Train-epoch 2. Iteration 00010, Avg-Loss: 0.4136, Accuracy: 0.8906
# Train-epoch 2. Iteration 00020, Avg-Loss: 0.4081, Accuracy: 0.8922
# Train-epoch 2. Iteration 00030, Avg-Loss: 0.4410, Accuracy: 0.8719
# Train-epoch 2. Iteration 00040, Avg-Loss: 0.4329, Accuracy: 0.8734
# Train-epoch 2. Iteration 00050, Avg-Loss: 0.4282, Accuracy: 0.8794
# Validation-epoch 2. Avg-Loss: 0.4656, Accuracy: 0.8811
# Train-epoch 3. Iteration 00010, Avg-Loss: 0.3972, Accuracy: 0.9000
# Train-epoch 3. Iteration 00020, Avg-Loss: 0.4156, Accuracy: 0.8828
# Train-epoch 3. Iteration 00030, Avg-Loss: 0.4107, Accuracy: 0.8802
# Train-epoch 3. Iteration 00040, Avg-Loss: 0.4175, Accuracy: 0.8773
# Train-epoch 3. Iteration 00050, Avg-Loss: 0.4185, Accuracy: 0.8744
# Validation-epoch 3. Avg-Loss: 0.4536, Accuracy: 0.8750
# Train-epoch 4. Iteration 00010, Avg-Loss: 0.3700, Accuracy: 0.8969
# Train-epoch 4. Iteration 00020, Avg-Loss: 0.3738, Accuracy: 0.9047
# Train-epoch 4. Iteration 00030, Avg-Loss: 0.3828, Accuracy: 0.8958
# Train-epoch 4. Iteration 00040, Avg-Loss: 0.3886, Accuracy: 0.8938
# Train-epoch 4. Iteration 00050, Avg-Loss: 0.4002, Accuracy: 0.8856
# Validation-epoch 4. Avg-Loss: 0.4440, Accuracy: 0.8811
# Train-epoch 5. Iteration 00010, Avg-Loss: 0.3815, Accuracy: 0.8906
# Train-epoch 5. Iteration 00020, Avg-Loss: 0.3804, Accuracy: 0.8891
# Train-epoch 5. Iteration 00030, Avg-Loss: 0.3779, Accuracy: 0.8854
# Train-epoch 5. Iteration 00040, Avg-Loss: 0.3924, Accuracy: 0.8781
# Train-epoch 5. Iteration 00050, Avg-Loss: 0.3872, Accuracy: 0.8831
# Validation-epoch 5. Avg-Loss: 0.4509, Accuracy: 0.8750
# Train-epoch 6. Iteration 00010, Avg-Loss: 0.3813, Accuracy: 0.8875
# Train-epoch 6. Iteration 00020, Avg-Loss: 0.3675, Accuracy: 0.8969
# Train-epoch 6. Iteration 00030, Avg-Loss: 0.3899, Accuracy: 0.8885
# Train-epoch 6. Iteration 00040, Avg-Loss: 0.3793, Accuracy: 0.8922
# Train-epoch 6. Iteration 00050, Avg-Loss: 0.3779, Accuracy: 0.8912
# Validation-epoch 6. Avg-Loss: 0.4331, Accuracy: 0.8811
# Train-epoch 7. Iteration 00010, Avg-Loss: 0.3859, Accuracy: 0.8906
# Train-epoch 7. Iteration 00020, Avg-Loss: 0.3471, Accuracy: 0.9047
# Train-epoch 7. Iteration 00030, Avg-Loss: 0.3631, Accuracy: 0.8969
# Train-epoch 7. Iteration 00040, Avg-Loss: 0.3648, Accuracy: 0.8961
# Train-epoch 7. Iteration 00050, Avg-Loss: 0.3661, Accuracy: 0.8925
# Validation-epoch 7. Avg-Loss: 0.4324, Accuracy: 0.8628
# Train-epoch 8. Iteration 00010, Avg-Loss: 0.3705, Accuracy: 0.8844
# Train-epoch 8. Iteration 00020, Avg-Loss: 0.3501, Accuracy: 0.8969
# Train-epoch 8. Iteration 00030, Avg-Loss: 0.3530, Accuracy: 0.9000
# Train-epoch 8. Iteration 00040, Avg-Loss: 0.3644, Accuracy: 0.8938
# Train-epoch 8. Iteration 00050, Avg-Loss: 0.3622, Accuracy: 0.8931
# Validation-epoch 8. Avg-Loss: 0.4186, Accuracy: 0.8811
# Train-epoch 9. Iteration 00010, Avg-Loss: 0.3540, Accuracy: 0.9031
# Train-epoch 9. Iteration 00020, Avg-Loss: 0.3389, Accuracy: 0.9109
# Train-epoch 9. Iteration 00030, Avg-Loss: 0.3491, Accuracy: 0.8979
# Train-epoch 9. Iteration 00040, Avg-Loss: 0.3516, Accuracy: 0.9047
# Train-epoch 9. Iteration 00050, Avg-Loss: 0.3501, Accuracy: 0.9031
# Validation-epoch 9. Avg-Loss: 0.4155, Accuracy: 0.8720
# Train-epoch 10. Iteration 00010, Avg-Loss: 0.3443, Accuracy: 0.8938
# Train-epoch 10. Iteration 00020, Avg-Loss: 0.3333, Accuracy: 0.8891
# Train-epoch 10. Iteration 00030, Avg-Loss: 0.3395, Accuracy: 0.8917
# Train-epoch 10. Iteration 00040, Avg-Loss: 0.3366, Accuracy: 0.8977
# Train-epoch 10. Iteration 00050, Avg-Loss: 0.3405, Accuracy: 0.8988
# Validation-epoch 10. Avg-Loss: 0.4104, Accuracy: 0.8811
# Train-epoch 11. Iteration 00010, Avg-Loss: 0.3666, Accuracy: 0.8812
# Train-epoch 11. Iteration 00020, Avg-Loss: 0.3363, Accuracy: 0.8984
# Train-epoch 11. Iteration 00030, Avg-Loss: 0.3341, Accuracy: 0.9021
# Train-epoch 11. Iteration 00040, Avg-Loss: 0.3351, Accuracy: 0.8992
# Train-epoch 11. Iteration 00050, Avg-Loss: 0.3360, Accuracy: 0.9006
# Validation-epoch 11. Avg-Loss: 0.4060, Accuracy: 0.8750
# Train-epoch 12. Iteration 00010, Avg-Loss: 0.3396, Accuracy: 0.9000
# Train-epoch 12. Iteration 00020, Avg-Loss: 0.3449, Accuracy: 0.8984
# Train-epoch 12. Iteration 00030, Avg-Loss: 0.3289, Accuracy: 0.9073
# Train-epoch 12. Iteration 00040, Avg-Loss: 0.3318, Accuracy: 0.9047
# Train-epoch 12. Iteration 00050, Avg-Loss: 0.3298, Accuracy: 0.9019
# Validation-epoch 12. Avg-Loss: 0.4032, Accuracy: 0.8841
# Train-epoch 13. Iteration 00010, Avg-Loss: 0.3696, Accuracy: 0.8750
# Train-epoch 13. Iteration 00020, Avg-Loss: 0.3334, Accuracy: 0.8891
# Train-epoch 13. Iteration 00030, Avg-Loss: 0.3264, Accuracy: 0.8958
# Train-epoch 13. Iteration 00040, Avg-Loss: 0.3239, Accuracy: 0.9016
# Train-epoch 13. Iteration 00050, Avg-Loss: 0.3223, Accuracy: 0.9019
# Validation-epoch 13. Avg-Loss: 0.3970, Accuracy: 0.8811
# Train-epoch 14. Iteration 00010, Avg-Loss: 0.3097, Accuracy: 0.9156
# Train-epoch 14. Iteration 00020, Avg-Loss: 0.3150, Accuracy: 0.9125
# Train-epoch 14. Iteration 00030, Avg-Loss: 0.3443, Accuracy: 0.8979
# Train-epoch 14. Iteration 00040, Avg-Loss: 0.3228, Accuracy: 0.9055
# Train-epoch 14. Iteration 00050, Avg-Loss: 0.3176, Accuracy: 0.9062
# Validation-epoch 14. Avg-Loss: 0.3958, Accuracy: 0.8720
# Train-epoch 15. Iteration 00010, Avg-Loss: 0.3215, Accuracy: 0.8844
# Train-epoch 15. Iteration 00020, Avg-Loss: 0.2814, Accuracy: 0.9203
# Train-epoch 15. Iteration 00030, Avg-Loss: 0.2955, Accuracy: 0.9146
# Train-epoch 15. Iteration 00040, Avg-Loss: 0.3054, Accuracy: 0.9078
# Train-epoch 15. Iteration 00050, Avg-Loss: 0.3060, Accuracy: 0.9081
# Validation-epoch 15. Avg-Loss: 0.3919, Accuracy: 0.8811
# Train-epoch 16. Iteration 00010, Avg-Loss: 0.3055, Accuracy: 0.9094
# Train-epoch 16. Iteration 00020, Avg-Loss: 0.3033, Accuracy: 0.9062
# Train-epoch 16. Iteration 00030, Avg-Loss: 0.3056, Accuracy: 0.9115
# Train-epoch 16. Iteration 00040, Avg-Loss: 0.3151, Accuracy: 0.9055
# Train-epoch 16. Iteration 00050, Avg-Loss: 0.3140, Accuracy: 0.9087
# Validation-epoch 16. Avg-Loss: 0.3859, Accuracy: 0.8750
# Train-epoch 17. Iteration 00010, Avg-Loss: 0.2859, Accuracy: 0.9156
# Train-epoch 17. Iteration 00020, Avg-Loss: 0.2768, Accuracy: 0.9250
# Train-epoch 17. Iteration 00030, Avg-Loss: 0.3077, Accuracy: 0.9115
# Train-epoch 17. Iteration 00040, Avg-Loss: 0.3002, Accuracy: 0.9156
# Train-epoch 17. Iteration 00050, Avg-Loss: 0.3002, Accuracy: 0.9113
# Validation-epoch 17. Avg-Loss: 0.3904, Accuracy: 0.8598
# Train-epoch 18. Iteration 00010, Avg-Loss: 0.2959, Accuracy: 0.9094
# Train-epoch 18. Iteration 00020, Avg-Loss: 0.2927, Accuracy: 0.9172
# Train-epoch 18. Iteration 00030, Avg-Loss: 0.2982, Accuracy: 0.9177
# Train-epoch 18. Iteration 00040, Avg-Loss: 0.2975, Accuracy: 0.9148
# Train-epoch 18. Iteration 00050, Avg-Loss: 0.2973, Accuracy: 0.9113
# Validation-epoch 18. Avg-Loss: 0.3823, Accuracy: 0.8811
# Train-epoch 19. Iteration 00010, Avg-Loss: 0.2558, Accuracy: 0.9219
# Train-epoch 19. Iteration 00020, Avg-Loss: 0.2791, Accuracy: 0.9125
# Train-epoch 19. Iteration 00030, Avg-Loss: 0.2885, Accuracy: 0.9115
# Train-epoch 19. Iteration 00040, Avg-Loss: 0.2772, Accuracy: 0.9180
# Train-epoch 19. Iteration 00050, Avg-Loss: 0.2871, Accuracy: 0.9150
# Validation-epoch 19. Avg-Loss: 0.3741, Accuracy: 0.8811
# Train-epoch 20. Iteration 00010, Avg-Loss: 0.2611, Accuracy: 0.9219
# Train-epoch 20. Iteration 00020, Avg-Loss: 0.2753, Accuracy: 0.9172
# Train-epoch 20. Iteration 00030, Avg-Loss: 0.2731, Accuracy: 0.9198
# Train-epoch 20. Iteration 00040, Avg-Loss: 0.2736, Accuracy: 0.9187
# Train-epoch 20. Iteration 00050, Avg-Loss: 0.2855, Accuracy: 0.9156
# Validation-epoch 20. Avg-Loss: 0.3768, Accuracy: 0.8720
# Train-epoch 21. Iteration 00010, Avg-Loss: 0.3111, Accuracy: 0.9000
# Train-epoch 21. Iteration 00020, Avg-Loss: 0.2987, Accuracy: 0.9031
# Train-epoch 21. Iteration 00030, Avg-Loss: 0.2866, Accuracy: 0.9187
# Train-epoch 21. Iteration 00040, Avg-Loss: 0.2766, Accuracy: 0.9242
# Train-epoch 21. Iteration 00050, Avg-Loss: 0.2713, Accuracy: 0.9275
# Validation-epoch 21. Avg-Loss: 0.3699, Accuracy: 0.8841
# Train-epoch 22. Iteration 00010, Avg-Loss: 0.2735, Accuracy: 0.9156
# Train-epoch 22. Iteration 00020, Avg-Loss: 0.2726, Accuracy: 0.9203
# Train-epoch 22. Iteration 00030, Avg-Loss: 0.2605, Accuracy: 0.9260
# Train-epoch 22. Iteration 00040, Avg-Loss: 0.2786, Accuracy: 0.9172
# Train-epoch 22. Iteration 00050, Avg-Loss: 0.2736, Accuracy: 0.9213
# Validation-epoch 22. Avg-Loss: 0.3714, Accuracy: 0.8811
# Train-epoch 23. Iteration 00010, Avg-Loss: 0.2530, Accuracy: 0.9187
# Train-epoch 23. Iteration 00020, Avg-Loss: 0.2581, Accuracy: 0.9234
# Train-epoch 23. Iteration 00030, Avg-Loss: 0.2748, Accuracy: 0.9198
# Train-epoch 23. Iteration 00040, Avg-Loss: 0.2738, Accuracy: 0.9219
# Train-epoch 23. Iteration 00050, Avg-Loss: 0.2751, Accuracy: 0.9200
# Validation-epoch 23. Avg-Loss: 0.3675, Accuracy: 0.8811
# Train-epoch 24. Iteration 00010, Avg-Loss: 0.2754, Accuracy: 0.9281
# Train-epoch 24. Iteration 00020, Avg-Loss: 0.2597, Accuracy: 0.9328
# Train-epoch 24. Iteration 00030, Avg-Loss: 0.2765, Accuracy: 0.9240
# Train-epoch 24. Iteration 00040, Avg-Loss: 0.2787, Accuracy: 0.9227
# Train-epoch 24. Iteration 00050, Avg-Loss: 0.2648, Accuracy: 0.9275
# Validation-epoch 24. Avg-Loss: 0.3653, Accuracy: 0.8780
# Train-epoch 25. Iteration 00010, Avg-Loss: 0.2503, Accuracy: 0.9219
# Train-epoch 25. Iteration 00020, Avg-Loss: 0.2605, Accuracy: 0.9234
# Train-epoch 25. Iteration 00030, Avg-Loss: 0.2616, Accuracy: 0.9198
# Train-epoch 25. Iteration 00040, Avg-Loss: 0.2577, Accuracy: 0.9234
# Train-epoch 25. Iteration 00050, Avg-Loss: 0.2666, Accuracy: 0.9213
# Validation-epoch 25. Avg-Loss: 0.3651, Accuracy: 0.8811
# Train-epoch 26. Iteration 00010, Avg-Loss: 0.2464, Accuracy: 0.9375
# Train-epoch 26. Iteration 00020, Avg-Loss: 0.2423, Accuracy: 0.9281
# Train-epoch 26. Iteration 00030, Avg-Loss: 0.2421, Accuracy: 0.9323
# Train-epoch 26. Iteration 00040, Avg-Loss: 0.2595, Accuracy: 0.9219
# Train-epoch 26. Iteration 00050, Avg-Loss: 0.2570, Accuracy: 0.9206
# Validation-epoch 26. Avg-Loss: 0.3680, Accuracy: 0.8780
# Train-epoch 27. Iteration 00010, Avg-Loss: 0.2911, Accuracy: 0.9156
# Train-epoch 27. Iteration 00020, Avg-Loss: 0.2712, Accuracy: 0.9187
# Train-epoch 27. Iteration 00030, Avg-Loss: 0.2639, Accuracy: 0.9260
# Train-epoch 27. Iteration 00040, Avg-Loss: 0.2597, Accuracy: 0.9297
# Train-epoch 27. Iteration 00050, Avg-Loss: 0.2586, Accuracy: 0.9287
# Validation-epoch 27. Avg-Loss: 0.3632, Accuracy: 0.8780
# Train-epoch 28. Iteration 00010, Avg-Loss: 0.2131, Accuracy: 0.9500
# Train-epoch 28. Iteration 00020, Avg-Loss: 0.2376, Accuracy: 0.9375
# Train-epoch 28. Iteration 00030, Avg-Loss: 0.2374, Accuracy: 0.9344
# Train-epoch 28. Iteration 00040, Avg-Loss: 0.2463, Accuracy: 0.9313
# Train-epoch 28. Iteration 00050, Avg-Loss: 0.2528, Accuracy: 0.9313
# Validation-epoch 28. Avg-Loss: 0.3613, Accuracy: 0.8720
# Train-epoch 29. Iteration 00010, Avg-Loss: 0.2431, Accuracy: 0.9313
# Train-epoch 29. Iteration 00020, Avg-Loss: 0.2517, Accuracy: 0.9328
# Train-epoch 29. Iteration 00030, Avg-Loss: 0.2625, Accuracy: 0.9250
# Train-epoch 29. Iteration 00040, Avg-Loss: 0.2584, Accuracy: 0.9273
# Train-epoch 29. Iteration 00050, Avg-Loss: 0.2491, Accuracy: 0.9325
# Validation-epoch 29. Avg-Loss: 0.3560, Accuracy: 0.8841
# Train-epoch 30. Iteration 00010, Avg-Loss: 0.2235, Accuracy: 0.9406
# Train-epoch 30. Iteration 00020, Avg-Loss: 0.2289, Accuracy: 0.9328
# Train-epoch 30. Iteration 00030, Avg-Loss: 0.2268, Accuracy: 0.9396
# Train-epoch 30. Iteration 00040, Avg-Loss: 0.2419, Accuracy: 0.9336
# Train-epoch 30. Iteration 00050, Avg-Loss: 0.2454, Accuracy: 0.9294
# Validation-epoch 30. Avg-Loss: 0.3579, Accuracy: 0.8811
# Train-epoch 31. Iteration 00010, Avg-Loss: 0.2186, Accuracy: 0.9375
# Train-epoch 31. Iteration 00020, Avg-Loss: 0.2301, Accuracy: 0.9375
# Train-epoch 31. Iteration 00030, Avg-Loss: 0.2340, Accuracy: 0.9354
# Train-epoch 31. Iteration 00040, Avg-Loss: 0.2369, Accuracy: 0.9352
# Train-epoch 31. Iteration 00050, Avg-Loss: 0.2357, Accuracy: 0.9331
# Validation-epoch 31. Avg-Loss: 0.3564, Accuracy: 0.8811
# Train-epoch 32. Iteration 00010, Avg-Loss: 0.2283, Accuracy: 0.9469
# Train-epoch 32. Iteration 00020, Avg-Loss: 0.2278, Accuracy: 0.9406
# Train-epoch 32. Iteration 00030, Avg-Loss: 0.2273, Accuracy: 0.9365
# Train-epoch 32. Iteration 00040, Avg-Loss: 0.2288, Accuracy: 0.9352
# Train-epoch 32. Iteration 00050, Avg-Loss: 0.2357, Accuracy: 0.9325
# Validation-epoch 32. Avg-Loss: 0.3540, Accuracy: 0.8780
# Train-epoch 33. Iteration 00010, Avg-Loss: 0.2124, Accuracy: 0.9500
# Train-epoch 33. Iteration 00020, Avg-Loss: 0.2261, Accuracy: 0.9437
# Train-epoch 33. Iteration 00030, Avg-Loss: 0.2206, Accuracy: 0.9448
# Train-epoch 33. Iteration 00040, Avg-Loss: 0.2356, Accuracy: 0.9375
# Train-epoch 33. Iteration 00050, Avg-Loss: 0.2400, Accuracy: 0.9356
# Validation-epoch 33. Avg-Loss: 0.3493, Accuracy: 0.8811
# Train-epoch 34. Iteration 00010, Avg-Loss: 0.2016, Accuracy: 0.9469
# Train-epoch 34. Iteration 00020, Avg-Loss: 0.2199, Accuracy: 0.9437
# Train-epoch 34. Iteration 00030, Avg-Loss: 0.2325, Accuracy: 0.9375
# Train-epoch 34. Iteration 00040, Avg-Loss: 0.2285, Accuracy: 0.9367
# Train-epoch 34. Iteration 00050, Avg-Loss: 0.2343, Accuracy: 0.9387
# Validation-epoch 34. Avg-Loss: 0.3526, Accuracy: 0.8780
# Train-epoch 35. Iteration 00010, Avg-Loss: 0.2011, Accuracy: 0.9531
# Train-epoch 35. Iteration 00020, Avg-Loss: 0.2459, Accuracy: 0.9391
# Train-epoch 35. Iteration 00030, Avg-Loss: 0.2276, Accuracy: 0.9427
# Train-epoch 35. Iteration 00040, Avg-Loss: 0.2289, Accuracy: 0.9398
# Train-epoch 35. Iteration 00050, Avg-Loss: 0.2326, Accuracy: 0.9375
# Validation-epoch 35. Avg-Loss: 0.3488, Accuracy: 0.8811
# Train-epoch 36. Iteration 00010, Avg-Loss: 0.2132, Accuracy: 0.9500
# Train-epoch 36. Iteration 00020, Avg-Loss: 0.2178, Accuracy: 0.9391
# Train-epoch 36. Iteration 00030, Avg-Loss: 0.2192, Accuracy: 0.9375
# Train-epoch 36. Iteration 00040, Avg-Loss: 0.2160, Accuracy: 0.9406
# Train-epoch 36. Iteration 00050, Avg-Loss: 0.2235, Accuracy: 0.9375
# Validation-epoch 36. Avg-Loss: 0.3468, Accuracy: 0.8841
# Train-epoch 37. Iteration 00010, Avg-Loss: 0.1993, Accuracy: 0.9500
# Train-epoch 37. Iteration 00020, Avg-Loss: 0.2311, Accuracy: 0.9344
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-37ff9e422055> in <module>
#     148 batchSize = 32
#     149
# --> 150 train_model(model, loss_fn, batchSize, trainset, valset, optimizer)
#
# <ipython-input-21-37ff9e422055> in train_model(model, loss_fn, batchSize, trainset, valset, optimizer)
#      44       # Make a pass over the training data.
#      45       #model.train()
# ---> 46       for (i, (inputs, labels)) in enumerate(train_loader):
#      47           #print(type(inputs))
#      48           inputs = inputs.cuda()
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in default_collate(batch)
#     230     elif isinstance(batch[0], container_abcs.Sequence):
#     231         transposed = zip(*batch)
# --> 232         return [default_collate(samples) for samples in transposed]
#     233
#     234     raise TypeError((error_msg.format(type(batch[0]))))
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in <listcomp>(.0)
#     230     elif isinstance(batch[0], container_abcs.Sequence):
#     231         transposed = zip(*batch)
# --> 232         return [default_collate(samples) for samples in transposed]
#     233
#     234     raise TypeError((error_msg.format(type(batch[0]))))
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in default_collate(batch)
#     207             storage = batch[0].storage()._new_shared(numel)
#     208             out = batch[0].new(storage)
# --> 209         return torch.stack(batch, 0, out=out)
#     210     elif elem_type.__module__ == 'numpy' and elem_type.__name__ != 'str_' \
#     211             and elem_type.__name__ != 'string_':
#
# KeyboardInterrupt:

# %%
#Confusion Matrix Part
import numpy as np
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import confusion_matrix

from sklearn.metrics import recall_score
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import label_binarize
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import confusion_matrix
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.utils.multiclass import unique_labels

import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import json, io, requests, string
from torch.utils.data.dataset import Dataset
from torchvision import transforms
import pandas as pd
import numpy as np

class_names = ['Glass', 'Paper', 'Cardboard', 'Plastic', 'Metal', 'Trash' ]
valset = torch.utils.data.TensorDataset(imgtensorVal, labeltensorVal)

score_list = []
label_list = []
ypred_list = []
y_pred = []
ytrue_list = []

def precisionrecall():
    batchSize = 5
#     model_load = torch.load("D:/trainedmodel_inceptionV3.pth")
    val_loader = torch.utils.data.DataLoader(dataset = valset,
                                             batch_size = batchSize,
                                             shuffle = False) # No need.
    model_load = torch.load("D:/Trash_Resnet_Replaced_layer.pth")


    model_load.eval()



    
    
    for (i, (inputs, labels)) in enumerate(val_loader):
        
        inputs = inputs.cuda()
        labels = labels.cuda()

        #           # Forward pass. (Prediction stage)
        scores = model_load(inputs)
        
        #            # Count how many correct in this batch.
        max_scores, max_labels = scores.max(1)
        y_pred.append(max_labels.cpu().tolist())

#         stores the scores and labels for computation of the precision recall curve
        score_list.append(scores.cpu().tolist())
        label_list.append(labels.view(-1).cpu().tolist())
        
    scoreholder = [[] for i in range(0,6)]

    class_counter = 0
    
    for class_counter in range(0,6):
        for i in score_list:
            for counter in  range(0,len(i)):
                try:
                    scoreholder[class_counter].append(i[counter][class_counter])
                except IndexError:
                    print(i)
                    break
                    
    for i in y_pred:
        for counter in  i:
            ypred_list.append(counter)
               


    precision = []

    ## Here we merge the datas of each epoch in tensor form (concantation)

    print(len(label_list))
    print(len(label_list[0]))
    
    print(len(score_list))
    print(len(score_list[0]))
    print(len(score_list[0][0]))
    
    for element in label_list:
        for subelement in element:

            ytrue_list.append(subelement)

    x = label_binarize(ytrue_list, classes=[0, 1, 2, 3, 4, 5])
    
    print(len(scoreholder[0]))
    print(len(x))
    
    
    precision= [0]*6
    recall = [0]*6
    average_precision = [0] * 6
    for i in range(0,6):
        precision[i], recall[i], _ = precision_recall_curve(x[:, i], np.asarray(scoreholder[i]))

        average_precision[i] = average_precision_score(x[:, i], np.asarray(scoreholder[i]))


    for i in range(0,6):
        plt.step(recall[i], precision[i], label= class_names[i], linewidth = 0.5)
    plt.legend()

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
#     plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
#               average_precision[1]))
    plt.savefig('precision-recall-resnet.png', dpi = 720)

    


                          
precisionrecall()
# Out:
# 66
# 5
# 66
# 5
# 6
# 328
# 328

# %%
#Confusion Matrix Part
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.utils.multiclass import unique_labels
import numpy as np
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import confusion_matrix


normalize = True
tensorino = torch.tensor([1])
ytrue_list = []

for element in label_list:
        for subelement in element:

            ytrue_list.append(subelement)

    
# print(tensorino)

print(np.asarray(ytrue_list))
class_names = ['Glass', 'Paper', 'Cardboard', 'Plastic', 'Metal', 'Trash' ]
print(confusion_matrix(ytrue_list, ypred_list))

# plot_confusion_matrix(np.asarray(ytrue_list[-1].tolist()), np.asarray(ypred_list[-1].tolist()), classes=class_names,
#                       normalize=False)
cm = confusion_matrix(ytrue_list,ypred_list)
piun = [0]*6
for i in range(0, cm.shape[1]):
    piun[i] =  np.ndarray.tolist(np.divide(cm[i],np.sum(cm[i])))

cm = np.asarray(piun)
fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap = plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
ax.set(xticks=np.arange(cm.shape[1]),
        yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
        xticklabels=class_names, yticklabels=class_names,
        title="Confusion Matrix",
        ylabel='True label',
        xlabel='Predicted label')
thresh = cm.max() / 1.5 if normalize else cm.max() / 2
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    if normalize:
            plt.text(j, i, "{:0.2f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    else:
        plt.text(j, i, "{:,}".format(cm[i, j]),
                    horizontalalignment="center",
                    color="white" if cm[i, j] > thresh else "black")
plt.xticks( rotation=30)
print(cm)
plt.imshow(cm, cmap = plt.cm.Blues)
# Out:
# [2 3 0 0 0 2 4 5 0 1 2 4 1 0 0 0 1 5 3 2 3 1 0 3 0 3 3 4 1 1 0 1 2 1 0 3 3
#  4 4 4 3 1 2 0 4 4 2 0 5 1 1 1 2 2 3 0 3 2 4 4 0 4 0 5 0 2 0 2 1 3 2 5 4 1
#  1 1 1 0 1 4 0 2 3 4 2 0 3 1 0 1 0 1 3 2 4 1 0 3 1 1 2 0 2 3 3 0 4 3 2 3 1
#  0 3 2 3 3 2 2 4 4 0 2 2 2 1 4 0 1 3 0 4 3 0 1 1 3 5 3 3 1 0 3 1 3 3 0 4 0
#  1 0 0 1 4 3 4 3 0 1 0 0 3 2 0 3 3 4 2 3 5 0 1 0 3 0 1 3 3 1 0 5 2 1 1 2 0
#  1 5 1 4 2 1 1 2 4 1 4 3 1 4 1 3 1 4 2 1 0 1 4 1 4 2 2 1 2 3 4 5 1 1 3 2 0
#  5 0 1 1 2 1 1 1 3 0 3 0 5 1 1 3 2 0 0 0 1 0 0 0 2 1 4 4 1 0 0 5 1 5 1 1 5
#  4 2 1 1 4 1 2 3 0 4 1 4 3 3 4 5 2 4 3 5 1 1 1 4 3 4 4 1 2 4 2 0 3 3 4 3 1
#  4 1 1 4 4 0 4 3 4 3 4 4 4 4 1 1 3 1 0 1 3 0 4 2 0 4 2 3 0 1 0 0]
# [[57  0  2  3  5  0]
#  [ 0 77  4  0  1  0]
#  [ 0  1 44  0  0  1]
#  [ 5  3  0 50  0  2]
#  [ 3  1  2  2 48  0]
#  [ 0  4  0  1  4  8]]
# [[0.85074627 0.         0.02985075 0.04477612 0.07462687 0.        ]
#  [0.         0.93902439 0.04878049 0.         0.01219512 0.        ]
#  [0.         0.02173913 0.95652174 0.         0.         0.02173913]
#  [0.08333333 0.05       0.         0.83333333 0.         0.03333333]
#  [0.05357143 0.01785714 0.03571429 0.03571429 0.85714286 0.        ]
#  [0.         0.23529412 0.         0.05882353 0.23529412 0.47058824]]

# %%
torch.save(model, "D:/Trash_Resnet_Replaced_layer.pth")

# %%
torch.save(model, "D:/Trash_Resnet_Replaced_layer_changed_lr_mid_run.pth")

# %%
model = torch.load("D:/Trash_Resnet_Replaced_layer.pth")
correct = 0.0
cum_loss = 0.0
batchSize = 5
#     model_load = torch.load("D:/trainedmodel_inceptionV3.pth")
val_loader = torch.utils.data.DataLoader(dataset = valset,
                                         batch_size = batchSize,
                                         shuffle = False) # No need.
model.eval()
for (i, (inputs, labels)) in enumerate(val_loader):
   inputs = inputs.cuda()
   labels = labels.cuda()


#           # Forward pass. (Prediction stage)
   scores = model(inputs)
   cum_loss += loss_fn(scores, labels.view(-1)).item()

#            # Count how many correct in this batch.
   max_scores, max_labels = scores.max(1)
   correct += (max_labels == labels.view(-1)).sum().item()

val_accuracies.append(correct / len(valset))
val_losses.append(cum_loss / (i + 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cf3d747ee12e> in <module>
#      15 #           # Forward pass. (Prediction stage)
#      16    scores = model(inputs)
# ---> 17    cum_loss += loss_fn(scores, labels.view(-1)).item()
#      18
#      19 #            # Count how many correct in this batch.
#
# NameError: name 'loss_fn' is not defined
